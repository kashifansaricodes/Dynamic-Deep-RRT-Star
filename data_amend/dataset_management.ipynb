# %% [markdown]
# This line writes how many paths have been generated for every environment

# %%
import csv


output_file = r"/home/sj/Deep-RRT-Star-Implementation/output.csv"
path_counts = {}
path_count = 0
temp = 0
with open(output_file, 'r') as file2:
    reader = csv.reader(file2)
    for row in reader:
        if row[-1] == 'image_number':
            continue
        if len(row) == 5:
            environment_number = int(row[-1])
            path_count += 1
            path_counts[environment_number] = path_count
            if temp != environment_number:
                path_count = 0
            # if environment_number == 82:
            #     print(row, path_count)
            temp = environment_number

no_path_file  =  r"/home/sj/Deep-RRT-Star-Implementation/data_amend/nopathfile.csv"
for i in range(len(path_counts)):
    with open(no_path_file, 'w', newline='') as file:
            writer = csv.writer(file)
            if file.tell() == 0: # Checks if the file is empty
                writer.writerow(['image_number', 'number_of_paths'])
            for environment_number, count in path_counts.items():
                writer.writerow([environment_number, count])
print(path_counts)
# Out:
# {0: 200, 1: 200, 10: 200, 100: 200, 101: 200, 102: 200, 103: 200, 104: 200, 105: 200, 106: 200, 107: 200, 108: 200, 109: 200, 11: 200, 110: 200, 111: 200, 112: 200, 113: 200, 114: 200, 115: 200, 116: 200, 117: 200, 118: 200, 119: 200, 12: 200, 120: 200, 121: 200, 122: 200, 123: 200, 124: 200, 125: 200, 126: 200, 127: 200, 128: 200, 129: 200, 13: 200, 130: 200, 131: 200, 132: 200, 133: 200, 134: 200, 135: 200, 136: 200, 137: 200, 138: 200, 139: 200, 14: 200, 140: 200, 141: 200, 142: 200, 143: 200, 144: 200, 145: 200, 146: 200, 147: 200, 148: 200, 149: 200, 15: 200, 150: 200, 151: 200, 152: 200, 153: 200, 154: 200, 155: 200, 156: 200, 157: 200, 158: 200, 159: 200, 16: 200, 160: 200, 161: 200, 162: 200, 163: 200, 164: 200, 165: 200, 166: 200, 167: 200, 168: 200, 169: 200, 17: 200, 170: 200, 171: 200, 172: 200, 173: 200, 174: 200, 175: 200, 176: 200, 177: 200, 178: 200, 179: 200, 18: 200, 180: 200, 181: 200, 182: 200, 183: 200, 184: 200, 185: 200, 186: 200, 187: 200, 188: 200, 189: 200, 19: 200, 190: 200, 191: 200, 192: 200, 193: 200, 194: 200, 195: 200, 196: 200, 197: 200, 198: 200, 199: 200, 2: 200, 20: 200, 21: 200, 22: 200, 23: 200, 24: 200, 25: 200, 26: 200, 27: 200, 28: 200, 29: 200, 3: 200, 30: 200, 31: 200, 32: 200, 33: 200, 34: 200, 35: 200, 36: 200, 37: 200, 38: 200, 39: 200, 4: 200, 40: 200, 41: 200, 42: 200, 43: 200, 44: 200, 45: 200, 46: 200, 47: 200, 48: 200, 49: 200, 5: 200, 50: 200, 51: 200, 52: 200, 53: 200, 54: 200, 55: 200, 56: 200, 57: 200, 58: 200, 59: 200, 6: 200, 60: 200, 61: 200, 62: 200, 63: 200, 64: 200, 65: 200, 66: 200, 67: 200, 68: 200, 69: 200, 7: 200, 70: 200, 71: 200, 72: 200, 73: 200, 74: 200, 75: 200, 76: 200, 77: 200, 78: 200, 79: 200, 8: 200, 80: 200, 81: 200, 82: 200, 83: 200, 84: 200, 85: 200, 86: 200, 87: 200, 88: 200, 89: 200, 9: 200, 90: 200, 91: 200, 92: 200, 93: 200, 94: 200, 95: 200, 96: 200, 97: 200, 98: 200, 99: 200}

# %% [markdown]
# These lines of code write new start goal examples required to be added in output.csv

# %%
import os
import cv2
import numpy as np
import random
import csv
import os

# Set the path to the images folder
images_folder = r"/home/sj/Deep-RRT-Star-Implementation/images"

def get_random_point(img):
    # Generate random x and y coordinates
    start_x = random.randint(0, width - 10)
    start_y = random.randint(0, height - 10)
    goal_x = random.randint(0, width - 10)
    goal_y = random.randint(0, height - 10)
    return start_x, start_y, goal_x, goal_y

# Create a list to store the start and goal points
points = []

output_file = r"/home/sj/Deep-RRT-Star-Implementation/data_amend/nopathfile.csv"
# Create a list to store the image paths
image_paths = []
with open(output_file, 'r') as file2:
    reader = csv.reader(file2)
    for row in reader:
        if row[-1] == 'number_of_paths':
            continue

        # m is the number of start and goal points to generate for each image
        m = int(row[-1])
        # print(m)

        # Get the image path
        image_path = "/home/sj/Deep-RRT-Star-Implementation/images/" + str(row[0]) + ".jpg"

        # Read the image
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        # Get the height and width of the image
        height, width = img.shape

        # Generate m random start and goal points
        for _ in range(200-m):

            # Get random start and goal points
            start_x, start_y, goal_x, goal_y = get_random_point(img)

            # Continue sampling until both start and goal points are white (255)
            while img[start_y, start_x] != 255 or img[goal_y, goal_x] != 255:
                start_x, start_y, goal_x, goal_y = get_random_point(img)

            file_name = os.path.basename(image_path)

            # Append the start and goal points to the list
            points.append([start_x, start_y, goal_x, goal_y, file_name[:-4]])

    print(points)
    # Set the path to the CSV file
    csv_file = r"/home/sj/Deep-RRT-Star-Implementation/data_amend/new_points.csv"

    # Write the start and goal points to the CSV file
    with open(csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['startx', 'starty', 'goalx', 'goaly', 'imagenumber'])
        writer.writerows(points)
        print("writing")

    print(f"Successfully generated {m} start and goal points for each image and saved them to {csv_file}.")
# Out:
# []
# writing
# Successfully generated 200 start and goal points for each image and saved them to /home/sj/Deep-RRT-Star-Implementation/data_amend/new_points.csv.

# %% [markdown]
# This code is related to deleting places where start_index appear equal to goal_index in output file

# %%
import csv
import csv
output_file = r"/home/sj/Deep-RRT-Star-Implementation/output.csv"
temp_output_file = r"/home/sj/Deep-RRT-Star-Implementation/temp_output.csv"
path_counts2 = {}
path_count2 = 0
temp2 = 0
total_faulty_paths = 0
line = 1
with open(output_file, 'r') as file2, open(temp_output_file, 'w', newline='') as temp_file:
# with open(output_file, 'r') as file2:
    reader = csv.reader(file2)
    temp_writer = csv.writer(temp_file)
    if temp_file.tell() == 0:
        temp_writer.writerow(['startx', 'starty', 'goalx', 'goaly', 'image_number'])
    for row in reader:
        if row[-1] == 'image_number':
            continue
        line += 1
        if len(row) == 5 and row[2] == row[3]:
            environment_number2 = int(row[-1])
            path_count2 += 1
            path_counts2[environment_number2] = path_count2
            if temp2 != environment_number2:
                path_count2 = 0
            temp2 = environment_number2
            total_faulty_paths += 1
            # print(row, line)
        else:
            temp_writer.writerow(row)
            
print(path_counts2)
print(total_faulty_paths)
print(line)
# Out:
# {}
# 0
# 653880

# %% [markdown]
# This block of code will go inside and write down start and goal index

# %%
import csv

output_file = r"/home/sj/Deep-RRT-Star-Implementation/output.csv"
temp_file_path = r"/home/sj/Deep-RRT-Star-Implementation/temp.csv"
goal_index_list = []
line = 0

with open(output_file, 'r', newline='') as file2, open(temp_file_path, 'w', newline='') as temp_file:
    reader = csv.reader(file2)
    writer = csv.writer(temp_file)
    if temp_file.tell() == 0:
        writer.writerow(['startx', 'starty', 'goalx', 'goaly', 'image_number'])
    for row in reader:
        # print(row)
        if row[-1] == 'image_number':
            continue
        if len(row) == 5:
            start_index = line
            row[2] = start_index 
            goal_index_list.append(start_index)
        writer.writerow(row)
        line += 1

# Renaming the temp file to replace the original file
import os
os.replace(temp_file_path, output_file)

# %%
print(goal_index_list)
# Out:
# [0, 11, 39, 62, 75, 92, 110, 118, 127, 145, 168, 172, 183, 190, 196, 207, 216, 223, 236, 241, 255, 260, 271, 281, 285, 304, 325, 337, 353, 356, 385, 398, 412, 421, 424, 426, 443, 466, 468, 481, 497, 507, 524, 537, 553, 566, 586, 597, 632, 648, 663, 676, 685, 707, 721, 733, 752, 783, 797, 802, 811, 830, 840, 857, 865, 881, 899, 918, 925, 947, 959, 971, 985, 988, 1004, 1009, 1028, 1031, 1038, 1044, 1050, 1055, 1078, 1094, 1110, 1121, 1142, 1158, 1178, 1193, 1206, 1223, 1241, 1248, 1262, 1271, 1280, 1295, 1303, 1316, 1327, 1343, 1363, 1366, 1378, 1395, 1409, 1415, 1419, 1424, 1437, 1443, 1447, 1455, 1468, 1487, 1493, 1497, 1508, 1518, 1537, 1565, 1573, 1580, 1592, 1596, 1600, 1613, 1629, 1644, 1664, 1679, 1688, 1701, 1719, 1736, 1760, 1774, 1780, 1790, 1804, 1813, 1825, 1837, 1850, 1868, 1888, 1901, 1915, 1926, 1941, 1954, 1962, 1977, 1997, 2013, 2032, 2041, 2045, 2050, 2062, 2071, 2082, 2099, 2108, 2121, 2139, 2153, 2169, 2181, 2187, 2206, 2214, 2221, 2231, 2235, 2248, 2257, 2267, 2280, 2289, 2299, 2315, 2318, 2340, 2363, 2385, 2397, 2401, 2406, 2420, 2426, 2442, 2464, 2473, 2489, 2516, 2541, 2550, 2571, 2596, 2617, 2628, 2647, 2664, 2681, 2706, 2708, 2728, 2754, 2778, 2788, 2807, 2819, 2838, 2858, 2863, 2880, 2917, 2926, 2930, 2957, 2996, 3003, 3011, 3033, 3042, 3057, 3081, 3083, 3087, 3113, 3124, 3128, 3165, 3176, 3206, 3223, 3230, 3252, 3284, 3303, 3323, 3344, 3351, 3354, 3365, 3376, 3400, 3416, 3434, 3439, 3446, 3471, 3478, 3489, 3504, 3517, 3533, 3553, 3556, 3587, 3600, 3611, 3625, 3632, 3641, 3649, 3651, 3662, 3682, 3691, 3717, 3724, 3729, 3744, 3769, 3771, 3777, 3789, 3801, 3831, 3838, 3853, 3873, 3896, 3910, 3921, 3926, 3932, 3948, 3964, 3978, 4001, 4012, 4026, 4038, 4060, 4068, 4081, 4112, 4115, 4130, 4164, 4178, 4205, 4231, 4261, 4272, 4300, 4304, 4327, 4357, 4377, 4385, 4389, 4391, 4406, 4427, 4439, 4462, 4482, 4489, 4517, 4523, 4545, 4555, 4572, 4579, 4596, 4619, 4640, 4673, 4703, 4712, 4717, 4737, 4751, 4755, 4775, 4790, 4810, 4816, 4841, 4871, 4881, 4907, 4915, 4925, 4945, 4965, 4987, 4998, 5024, 5054, 5073, 5086, 5111, 5126, 5151, 5173, 5189, 5206, 5248, 5273, 5286, 5299, 5345, 5379, 5389, 5394, 5409, 5442, 5453, 5470, 5486, 5509, 5542, 5565, 5572, 5576, 5580, 5594, 5602, 5612, 5633, 5663, 5688, 5697, 5719, 5723, 5747, 5783, 5801, 5827, 5845, 5854, 5888, 5892, 5899, 5902, 5941, 5964, 5969, 5989, 6002, 6010, 6019, 6038, 6061, 6073, 6082, 6108, 6115, 6120, 6145, 6152, 6164, 6179, 6193, 6195, 6216, 6224, 6256, 6273, 6299, 6311, 6340, 6361, 6367, 6371, 6396, 6423, 6427, 6459, 6482, 6503, 6529, 6554, 6570, 6595, 6609, 6635, 6655, 6661, 6682, 6705, 6723, 6736, 6759, 6777, 6783, 6813, 6830, 6835, 6843, 6863, 6868, 6893, 6923, 6950, 6963, 6968, 6979, 6982, 7013, 7026, 7051, 7073, 7097, 7120, 7130, 7154, 7176, 7197, 7208, 7217, 7246, 7271, 7283, 7303, 7315, 7334, 7346, 7363, 7370, 7386, 7397, 7415, 7436, 7461, 7466, 7470, 7483, 7505, 7520, 7527, 7530, 7562, 7572, 7580, 7610, 7631, 7646, 7673, 7687, 7715, 7745, 7748, 7776, 7780, 7788, 7813, 7834, 7843, 7851, 7880, 7885, 7920, 7937, 7939, 7965, 7978, 7993, 8005, 8012, 8020, 8033, 8057, 8078, 8104, 8121, 8155, 8178, 8194, 8206, 8236, 8270, 8284, 8318, 8328, 8351, 8357, 8370, 8381, 8389, 8416, 8434, 8457, 8477, 8496, 8511, 8536, 8566, 8573, 8583, 8606, 8636, 8657, 8659, 8672, 8680, 8683, 8706, 8722, 8740, 8751, 8769, 8800, 8820, 8828, 8850, 8887, 8903, 8906, 8921, 8941, 8961, 8986, 8996, 9012, 9027, 9037, 9045, 9063, 9073, 9094, 9096, 9102, 9113, 9121, 9150, 9169, 9195, 9233, 9268, 9271, 9286, 9304, 9337, 9351, 9372, 9398, 9419, 9428, 9447, 9472, 9488, 9508, 9525, 9534, 9548, 9556, 9566, 9573, 9591, 9596, 9611, 9621, 9628, 9648, 9651, 9670, 9691, 9705, 9727, 9730, 9732, 9758, 9764, 9774, 9792, 9799, 9816, 9840, 9844, 9860, 9881, 9891, 9899, 9916, 9933, 9938, 9960, 9966, 9989, 10003, 10012, 10015, 10021, 10032, 10050, 10072, 10093, 10095, 10100, 10123, 10128, 10134, 10147, 10153, 10157, 10173, 10190, 10209, 10224, 10245, 10255, 10272, 10279, 10296, 10301, 10311, 10327, 10335, 1 ...

# %%
import csv

output_file = r"/home/sj/Deep-RRT-Star-Implementation/output.csv"
temp_file_path = r"/home/sj/Deep-RRT-Star-Implementation/temp2.csv"
# Example list of goal indices, replace with your actual data
line = 1

with open(output_file, 'r', newline='') as file2, open(temp_file_path, 'w', newline='') as temp_file:
    reader = csv.reader(file2)
    writer = csv.writer(temp_file)
    
    # Write header if the temp file is empty
    if temp_file.tell() == 0:
        writer.writerow(['startx', 'starty', 'goalx', 'goaly', 'image_number'])
    
    # Iterate over the rows in the input CSV file
    for row in reader:
        if row[-1] == 'image_number':
            continue
        if len(row) == 5 and line < len(goal_index_list):
            goal_index = goal_index_list[line] 
            row[3] = goal_index -1 
            line += 1 
        writer.writerow(row)

# Renaming the temp file to replace the original file
import os
os.replace(temp_file_path, output_file)
